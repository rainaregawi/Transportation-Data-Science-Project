# %% [markdown]
# <a href="https://colab.research.google.com/github/rainaregawi/Transportation-Data-Science-Project/blob/main/Explorer_TDSP_Rahwa_Aregawi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚗 **Welcome to the <font color='crimson'>** **Explorer Transportation Data Science Project! 🚗**</font>
#  Hosted by the [Northeast Big Data Innovation Hub](https://nebigdatahub.org/about) & [National Student Data Corps](https://nebigdatahub.org/nsdc), in collaboration with the [U.S. Department of Transportation Federal Highway Administration](https://highways.dot.gov/).
#
#
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
#
# By participating in this project, you are joining a
# community of transportation data science learners interested in making roads safer for vulnerable road users.
#
# The Explorer TDSP has six Milestones, including guided transportation research into a community of interest. Each Milestone can take 1-5 hours, or less, depending on your level of experience.
#
# To learn more about this project, including key highlights, incentives, and important links, [review the TDSP Webpage here](https://nebigdatahub.org/nsdc/tdsp/)!

# %% [markdown]
# ## <font color='crimson'>**How to Get Started:**</font>

# %% [markdown]
# In order to work within this Google Colab Notebook, **please start by clicking on "File" in the top left corner of your notebook, and then "Save a copy in Drive." Rename the file to "Explorer TDSP - Your Full Name."** This will save a copy of the notebook in your personal Google Drive.
#
# You may now begin!

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**A Quick Introduction to Google Colab**</font>

# %% [markdown]
# Read below for a Google Colab QuickStart:
# - Google Colab is a Python Notebook environment built by Google that's free for all.
# - Colab Notebooks are made up of cells; cells can be either *text* or *code* cells. You can click the +code or +text button at the top of the Notebook to create a new cell.
# - Text cells use a format called [Markdown](https://www.markdownguide.org/getting-started/). Knowledge of Markdown is not required for this project. However, if you'd like to learn more, [check out this Cheatsheet!](https://www.markdownguide.org/cheat-sheet/)
# - Python code is executed in *code* cells. When you want to run your code, hover your cursor over the square brackets in the top left corner of your code cell. You'll notice a play button pop up! (▶) Click the play button to run the code in that cell. Code cells run one at a time.
# - The memory shared across your notebook is called the *Runtime*. You can think of a Runtime as a "code session" where everything you create and execute is temporarily stored.
# - Runtimes will persist for a short period of time, so you are safe if you need to refresh the page, but Google will shutdown a Runtime after enough time has passed. Everything that you have printed out will remain within your Notebook even if the runtime is disconnected.
#
# If this is your first time using Google Colab, we highly recommend reviewing the [NSDC's *Using Google Colab Guide*](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf) before continuing. For a more comprehensive guide, see [Colab's *Welcome To Colaboratory* walkthrough.](https://colab.research.google.com/github/prites18/NoteNote/blob/master/Welcome_To_Colaboratory.ipynb)

# %% [markdown]
# ## <font color='crimson'>**An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# **Let's review some essential Python Functions!**
#
# Here are some key functions you'll frequently encounter:
#
# 1. **`head()`**: This function is crucial for getting a quick overview of your dataset. By default, it returns the first five rows, offering a snapshot of your data's structure and values.
#
# 2. **`describe()`**: This provides a summary of the statistical characteristics of your dataset. It's particularly useful for gaining insights into the distribution, mean, standard deviation, and range of numerical columns.
#
# 3. **`sum()`**: This calculates the total sum of a column or a series of numbers, proving essential for quick calculations and aggregations in data analysis.
#
# 4. **`isnull()`**: This helps identify missing or null values in your dataset, allowing for effective data cleaning and preprocessing.
#
# 5. **`value_counts()`**: Understanding the frequency of various values in your dataset is a common task in data science. The `value_counts()` function makes this easy by counting the occurrence of each unique value in a column.
#
# Now that you've reviewed these important concepts, let's dive in to the project!

# %% [markdown]
# ## <font color='crimson'>**Milestone #1 - Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up your environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that you can use in your programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# These are the libraries that will help us throughout this project. We invite you to research each library for a better understanding.
#
# We encourage you to read more about the important and most commonly used libraries like Pandas, Matplotlib, and Seaborn and write a few lines in your own words about what they do. [You may use the Data Science Resource Repository (DSRR) to find resources to get started!](https://nebigdatahub.org/nsdc/data-science-resource-repository/)

# %% [markdown]
# **TO DO:** Write a few lines about what each library does:
#
#
#
#
# > * Pandas: open-source python library designed for data manipulation and analysis. It can be used to read, write, clean, transform, merge and join data. It provides data structures series and dataframes. Helpful for creating different visualizations for datasets.
# > * Matplotlib: plotting library designed for creating static, interactive, and animated visualizations in various formats. It also includes basic plotting, customization, multiple plot types, and support for subplots.
# > * Seaborn: data visualization library built on top of matplotlib. It offers more advanced statistical plots and simplified syntax. Integrates well with pandas.

# %% [markdown]
# **Step 2:** Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC." If you need a reminder on how to upload your dataset, [please review helpful hints here.](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf)
#
# Since this is a large dataset, we highly recommend that you upload your data by [mounting your Google Drive](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA).
#
# To mount your Google Drive, begin by finding the folder icon on the left side of your screen. When you click on this folder icon, you will open the Files window. Click on the icon at the top of the Files window that says "Mount Drive" as you hover over it.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, we will read the data using the `pd.read_csv` function.
# Ensure that you've downloaded the dataset from NYC OpenData, and uploaded the dataset to your Google Drive.

# %% [markdown]
# Hint: Your data's file path describes the location of where your data lives. To locate your data's file path, click on the folder/file-shaped icon on the left side of the Notebook. You'll notice a folder labeled "drive." Search for your Motor Vehicle Collisions Dataset within that folder. Right click on your Dataset to "copy path." Paste that path below.

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250106.csv")
# Out:
# <ipython-input-29-33082758963b>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250106.csv")

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
print(data.head())
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
# TODO: Describe the data using the describe function of pandas
desc_stats = data.describe()
desc_stats
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.907702e+06  1.907702e+06               2.147232e+06
# mean   4.062039e+01 -7.373882e+01               3.195314e-01
# std    2.052928e+00  3.845923e+00               7.080287e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066755e+01 -7.397469e+01               0.000000e+00
# 50%    4.072055e+01 -7.392705e+01               0.000000e+00
# 75%    4.076962e+01 -7.386674e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.147219e+06                   2.147250e+06
# mean               1.541995e-03                   5.812272e-02
# std                4.144300e-02                   2.472097e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  2.147250e+06               2.147250e+06
# mean                   7.623705e-04               2.795809e-02
# std                    2.816839e-02               1.669888e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              2.147250e+06                2.147250e+06
# mean               1.206194e-04                2.292337e-01
# std                1.102435e-02                6.691821e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count               2.147250e+06  2.147250e+06
# mean                6.342997e-04  3.212753e+06
# std                 2.754466e-02  1.507073e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  3.172932e+06
# 50%                 0.000000e+00  3.709890e+06
# 75%                 0.000000e+00  4.246934e+06
# max                 5.000000e+00  4.784001e+06

# %% [markdown]
# The information above is currently formatted in scientific notation. Need a refresher? [Review how to analyze and convert to and from scientific notation here!](https://www.mathsisfun.com/numbers/scientific-notation.html)
#
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #2 - Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# **Step 1:**
# Before we begin assessing our data for missing values, it is important that we understand the ethical implications surrounding data processing. To best prepare yourself for this module, review one or more of the following resources:
# - [Data Science Ethics Flashcard Video Series](https://youtube.com/playlist?list=PLNs9ZO9jGtUB7XTjXy-ttoo2QSLld9SrV&feature=shared)
# - [What Do I Need to Understand about Data Ethics?](https://www.youtube.com/watch?v=Efy8htCDueE)
# -[Introduction to Data Cleaning](https://www.youtube.com/watch?v=t8WkoGLkdTk)
#
# **TO DO:** Based on the resources above and outside knowledge, what are some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities? How might bias show up in our dataset?
#
# > Answer here: There may be differences in how data is collected between well-resourced and under-resourced communities, which could be influenced by a range of factors, including social, racial, and economic considerations. While these differences may be unintentional, they could introduce biases in the data. Under-resourced communities may face limitations in the resources available for thorough investigations, and there could be disparities in traffic enforcement or accident reporting. For instance, crashes in these communities might be underreported, or there may be a greater focus on other types of incidents, affecting the overall accuracy and representation of the data. Biases might show up in the dataset as incomplete or missing data, geographic disparities and a lack of data quality.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
#TODO: Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = data.isnull().sum()

#TODO: Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100

#TODO: Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_values_percentage
    })
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   2137940       99.566422
# CONTRIBUTING FACTOR VEHICLE 5         2137644       99.552637
# VEHICLE TYPE CODE 4                   2113338       98.420678
# CONTRIBUTING FACTOR VEHICLE 4         2112079       98.362044
# VEHICLE TYPE CODE 3                   1998431       93.069321
# CONTRIBUTING FACTOR VEHICLE 3         1992605       92.797997
# OFF STREET NAME                       1778512       82.827430
# CROSS STREET NAME                      818686       38.127186
# ZIP CODE                               665926       31.012970
# BOROUGH                                665663       31.000722
# ON STREET NAME                         461111       21.474491
# VEHICLE TYPE CODE 2                    420694       19.592223
# CONTRIBUTING FACTOR VEHICLE 2          338705       15.773897
# LOCATION                               239548       11.156037
# LONGITUDE                              239548       11.156037
# LATITUDE                               239548       11.156037
# VEHICLE TYPE CODE 1                     14914        0.694563
# CONTRIBUTING FACTOR VEHICLE 1            7301        0.340016
# NUMBER OF PERSONS KILLED                   31        0.001444
# NUMBER OF PERSONS INJURED                  18        0.000838
# COLLISION_ID                                0        0.000000
# CRASH DATE                                  0        0.000000
# NUMBER OF MOTORIST KILLED                   0        0.000000
# NUMBER OF MOTORIST INJURED                  0        0.000000
# NUMBER OF CYCLIST KILLED                    0        0.000000
# CRASH TIME                                  0        0.000000
# NUMBER OF PEDESTRIANS KILLED                0        0.000000
# NUMBER OF PEDESTRIANS INJURED               0        0.000000
# NUMBER OF CYCLIST INJURED                   0        0.000000

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
#TODO: Plot a Bar Chart

top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)


plt.figure(figsize=(12, 7))
# TODO: Plotting the top contributing factors, fill in x as the index field of the variable 'top_factors'
sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")
plt.title('Top 10 Contributing Factors to crashes', fontsize=16)
plt.xlabel('Contributing Factors', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-35-bb028df9ea3d>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

# %% [markdown]
# **TO DO:** Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Driver Inattention/Distraction
# > *  Failure to Yield Right-of-Way
# > *  Following Too Closely

# %% [markdown]
# **TO DO:** What recommendations would you make to new and current drivers after assessing the above data?
#
# > *   I would recommend drivers to avoid avoid any distractions while driving, such as using hand-held devices or eating since this can impact their focus and reaction times. It's important to follow traffic rules and drive cautiously. This includes yielding when necessary, maintaining a safe following distance, and avoidning unsafe backing, improper lane usage, and passing too closely. Additionally, turning improperly or without singlaning can lead to accidents.

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to determine which vehicle types were involved in the most crashes.

# %%
# Determine the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")
plt.title('Top 10 Vehicle Types Involved in crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-36-d81efa66963e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")

# %% [markdown]
# **TO DO:** What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedan
# > *   Station Wagon/Sport Utility Vehicle
# > *   Passenger Vehicle

# %% [markdown]
# **TO DO:** Why do you think that "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" are involved in a more number of crashes, injuries, and deaths when compared to the rest of the vehicles? (Think outside the box!)
#
#
# > I imagine the higher involvment of "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" in crashes, injuries, and deaths can be attributed to prevalence, driving patterns, driving environments, and the categorization of vehicle types in the dataset:
#
# > * The vehicles most commonly involved in crashes are likely those that are most prevalent on the road, such as sedans, station wagons, and passenger vehicles. For example, sedans are a common type of vehicle seen on the road.
#
# > * Taxis, which are often sedans or SUVs, might have different driving patterns compared to non-taxi vehicles. Taxi drivers might adhere more strictly to traffice rules due to professional responsibilities. The top contributing factors include distractions and poor traffic etiquete, which might explain the difference between sedans and taxi drivers even though they commonly use similar vehicle types.
#
# > * These types of vehicles are commonly seen together on the road, particularly where there is higher traffic density. In contrast, trucks, which are often used for long-distance travel, tend to be on less congested roads, where the likelihood of collisions might be lower.
#
# > * The "PASSENGER VEHICLE" category, which includes many types of vehicles (sedans, vans, station wagons, taxis, etc), is more likely to show higher numbers since it encompasses a broad range of vehicles already listed separately. This overlap could mean its heavily represented in the dataset, contributing to the higher numbers of crashes, injuries, and deaths in this category.

# %% [markdown]
# **TO DO:** Review the x-axis of the bar chart you created above. </br>
# 1) What do you notice? </br>
# 2) What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why? </br>
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
#
# > *  1)  I noticed the titles are similar or the same. For example, one bar depicts "Station Wagon/Sport Utility Vehicle" and another bar represents "SPORT UTILITY / STATION WAGON". There is also one bar for "Sedan" and another for "4 dr sedan". There's one bar for "Taxi" and another for "TAXI". This could lead to unnecessary repitition in the data representation. There is also a category for "PASSENGER VEHICLE". Passenger vehicles include various types of vehicles, particularly some that are already listed - sedans, taxis, vans, and station wagons.This could cause overlap and skew the data representation.
# > *  2) I recommend standardizing the labels so that variations in wording or capitalization are eliminated. Also the category "PASSENGER VEHICLE" can be simplified. Combining similar data (such as "Taxi" and "TAXI") into a single category will make the chart clearer and more accurate. This will also make the chart more readable and avoid visual clutter from duplicated categories.
# > *  3) I recommend those collecting and/or inputting data ensure consistency in labeling. They should use a standardized format for category names and avoid variations in capitalization, spelling, phrasing, as well as eliminate overlapping categories. For example, using "Sedan" consistently and avoiding alternative representations like "4 dr sedan" will make it easier to aggregate and analyze the data accuretly. A standardized format will also improve the quality and reliability of the dataset for future analysis.

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.
#
# Let's graph the *types* of crashes within this dataset and their frequencies. Begin by aggregating your data, convert to [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) for simple plotting, and plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorist Deaths': data['NUMBER OF MOTORIST KILLED'].sum()
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-37-1d14d8e1a468>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# **TO DO:** Analyze the chart above. What is a recommendation you might make to the Department of Transportation based on this data?
#
#
# > *  I recommend that the Department of Transportation prioritize reducing motorist injuries. This can be achieved by addressing key factors such as distracted driving and promoting safe vehicle practices. Enhancing driver education and awareness, implementing stricter traffic enforcement, and utilizing advanced traffic technologies, such as smart traffic lights and congestion management systems, could all contribute to safer roadways. To address pedestrian and cyclist injuries, which are the following leading types of crashes, I recommend improving infrastructure, such as crosswalks and lighting, while promoting cyclist safety through the expansion of protected bike lanes.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #3 - Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Before we jump into Time Series Analysis (TSA), it's important to understand the basics, including Trends, Seasonality, and Residual Components.
#
# Review one or more of the following resources and tell us what you learned about TSA!
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **TO DO:** Write 3-5 sentences about TSA.
# > *  Time Series Analysis (TSA) is a statistical method that examines data collected over time, revealing patterns and trends to provide valuable insights for developing accurate forecasting models. TSA comprises of systematic (trend, seasonality, level) and unsystematic (noise) components to reveal underlying data patterns. By understanding these components, we can gain a deeper understanding of the data's behavior and make more informed predictions about future values.

# %% [markdown]
# **Step 2:** Let's begin by creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = "/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250106.csv"
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M')

# Time of Day Analysis
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes per hour
average_crashes_per_hour = data.groupby('Hour of Day').size() / data['Hour of Day'].nunique()

# Plot the average number of crashes
plt.figure(figsize=(12, 6))
sns.barplot(x=average_crashes_per_hour.index, y=average_crashes_per_hour.values)
plt.title('Average Number of crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Number of crashes')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-38-aea6f6aa1f1c>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %% [markdown]
# **TO DO:** Which time of the day sees the most crashes? Why do you think so?
#
# > *  The time of the day that sees the most crashes, according to the chart, is the 16th hour, corresponding to 4:00 pm. This is the case because rush hour is when there are a lot of vehicles on the road, which increases the chance of crashes.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period("M")).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot()
plt.title('Number of Crashes per Month', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** What does your graph tell you about the impact of COVID-19 on the number of crashes per month? Why do you think this occurred?
#
# > *  The graph illustrates a significant decrease in the number of crashes per month between 2019 and 2020, coinciding with the onset of the COVID-19 pandemic and the implementation of lockdown measures. The decline is likely due to reduced traffic volume as people stayed home, worked remotely, and limited non-essential travel. The restrictions on movement and social gatherings resulted in fewer vehicles on the roads, thereby reducing chances for collisions.

# %% [markdown]
# **Step 4**: Apply time series decomposition to review trends, seasonality, and residuals. New to time series analysis? Review the [Time Series Flashcard video series](https://youtube.com/playlist?list=PLNs9ZO9jGtUAqd0CNKySksPJJaOqYPMvk&feature=shared) here to learn about trends, components, and further analysis!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby('CRASH DATE').size()
# Set plot style
sns.set(style="darkgrid")
# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes, label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Date')
plt.ylabel('Number of crashes')
plt.legend()
plt.show()
# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)
# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasonality')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# **TO DO:** Based on your *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# > *  Between 2014 and 2019, a steady and slightly increasing trend exists. After 2019, the trend decreased sharply and then increased and became steady.
#
#
# **TO DO:** Based on your *residual graph*, in what year(s) was there a significant unpredicted fluctuation? Why do you think so?
#
# > *  Between 2020 and 2021, there is a fluctuation in the graph that is probably due to the impact of the COVID-19 pandemic.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #4 - Geospatial Analysis**</font>
# GOAL: The main goal of this milestone is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# **Step 1:** Before beginning this Milestone, we highly recommend that you review the [NSDC Geospatial Analysis Flashcard Video series](https://www.youtube.com/playlist?list=PLNs9ZO9jGtUAX_2g1-OJp8VkmVum6DqqP) if you are new to Geospatial Analysis!
#
# Let's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
#TODO: Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))
# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-41-4f14068022f4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# **TO DO:** Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest: Brooklyn
# > * Lowest: Staten Island
#
#
# **TO DO:** Are there any reasons that you think a certain borough has a higher or lower number of crashes? What are some factors that may be causing this?
#
# > *  As of 2022, Brooklyn's population is 2.68 million<sup>[1](https://datacommons.org/place/geoId/3604710022?utm_medium=explore&mprop=count&popt=Person&hl=en)</sup> and Staten Island has a population of 492,925<sup>[2](https://datacommons.org/place/geoId/3608570915?utm_medium=explore&mprop=count&popt=Person&hl=en)</sup>. The significant difference in population could be a contributing factor as to why Brooklynn has the highest number of crashes and Staten Island has the lowest. Higher traffic density could increase the chances of crashes. Notes that Queens has a population of 2.361 million<sup>[3](https://datacommons.org/place/geoId/3608160323?utm_medium=explore&mprop=count&popt=Person&hl=en)</sup>, Manhattan has a population of 1.646 million<sup>[4](https://datacommons.org/place/geoId/3606144919?utm_medium=explore&mprop=count&popt=Person&hl=en)</sup>, and Bronx has a population of 1.443 million<sup>[5](https://datacommons.org/place/geoId/3600508510?utm_medium=explore&mprop=count&popt=Person&hl=en)</sup>.

# %% [markdown]
# **Step 2:** Heatmaps are graphical representations that use color coding to represent different values and variables. Let's leverage a heatmap to determine the most dangerous intersections in the dataset. (**Note: the below cell may take a few minutes to run**)

# %%
#TODO: Create a heatmap leveraging the latitude and longitude variables to determine where the most crashes are occurring
from folium.plugins import HeatMap

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)  # Centered around NYC

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

m.save("Heatmap.html")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Click on that icon to find the file titled "Heatmap.html". Click on the three dots next to your file and download your heatmap! Open the file once downloaded to see your creation.
#
# When looking at your heatmap, where do you see a concentration of crashes?
#
#
# > *  A concentration of crashes Lower Manhattan, Midtown, Downtown Brooklyn, and further out in Far Rockaway.

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about your map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
#TODO: Continue building your heatmap
# Sample a subset of the data for visualization
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "RED"  # Fatalities

        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=3,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "PURPLE"  # Injuries
        folium.CircleMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          radius=5,
          color=color,
          fill=True,
          fill_color=color
       ).add_to(m_severity)
    else:
        color = "GRAY"  # No injuries or fatalities
        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=4,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


m_severity.save("severity.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Follow the same steps as above to download the "Severity.html" file.
#
# **TO DO:** Which intersection(s) seem to be the most dangerous?
#
# > *  Cross Bay BLVD heading towards Joseph P. Addabbo Memorial Bridge in Queens; on the Korean War Veterans Parkway between Huguenot Ave. & Albee Ave. in Staten Island.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='crimson'>  **Milestone #5 - Self-Guided Research Question**</font>
# GOAL: In this Milestone, you will be prompted to take what you’ve learned throughout this project, build your own research question, and create a visualization(s) or model(s) to support your research goals.

# %% [markdown]
# You may create your visualization(s) in this Colab Notebook, or in Excel, Tableau, PowerBI, etc. Choose whichever medium you are most comfortable with! Be creative!
#
# For participants who are comfortable with advanced data science techniques, we welcome you to leverage additional datasets, if desired. We highly recommend using pre-cleaned datasets from open data sources, like Kaggle.com.
#
# If you have any questions or get stuck, please email nsdc@nebigdatahub.org with your queries. We're here to help!

# %% [markdown]
# **Step 1:** Review the dataset(s) that you will be using. As you explore, [consider the research question you want to answer](https://libraries.indiana.edu/sites/default/files/Develop_a_Research_Question.pdf)! Additionally, think about [who you are telling your data's story to](https://hbr.org/2013/04/how-to-tell-a-story-with-data). Your final audience may contain a group of transportation professionals, data scientists, peers, and the general public. Think about how would you frame your analysis differently for each of these groups.

# %% [markdown]
# **TO DO:** List one or more research questions here that you are considering.
#
# > *  I'm intersted in considering questions related to crash frequency by zip code, intersections in Brooklyn, and the impact of weather conditions.

# %% [markdown]
# **Step 2:** Now, think about what type of analysis you'd like to complete. Are you interested in looking at time series forecasting? Do you have additional maps in mind that you'd like to create? Is there a certain zip code or region you'd like to dive deeper into?
#
# If you happen to be stuck, here are some examples that you can use or can guide you in choosing your research question!
#
# **Examples:**
# - How many crashes, injuries, and/or fatalies occurred in a zip code of interest?
# - Which zip code sees the highest amount of crashes and what recommendations can you offer to help that community? Is it an underserved community?
# - Do more crashes occur in underrepresented communities? Support your conclusion.
# - Which day of the week sees the most crashes, injuries, and/or fatalities? (Hint: use the same method we used when we were analyzing the average number of crashes at different times of the day!)
# - Does the geometric features of an intersection (90 degree intersection vs skewed intersection) affect the number of crashes that occur?
#
# Be creative and think outside the box!

# %% [markdown]
# **Step 3:** Now that you've decided on your transportation research question, [explore the various types of visualizations you can create to support your research](https://datavizcatalogue.com/). You may create visualizations in this Google Colab notebook, Excel, R, SQL, PowerBI, Tableau, etc. Choose a program you are comfortable with!
#
# You may also choose to build a model or leverage a different data science technique based on your experience level.

# %% [markdown]
# **Step 4:** Consider the **accessibility** of the graphs, charts, maps, or models you are interested in building. Use the tools below to learn more!
# * How does your visualization appear to people [who may not be able to distinguish between muted colors or see your chart at all?](https://chartability.fizz.studio/)
# *[Color Contrast Checker](https://policyviz.com/2022/11/01/color-contrast-checker-in-excel/)
# *[SAS Graphics Accelerator](https://support.sas.com/software/products/graphics-accelerator/index.html)
# *[TwoTone Data Sonification Tool](https://twotone.io/about/)
# *[Making Visual Studio Accessible](https://code.visualstudio.com/docs/editor/accessibility)

# %% [markdown]
# To make visualizations more inclusive for people with color blindness, you can choose a color palette that is colorblind-friendly. `Seaborn`, a Python visualization library, provides several palettes that are designed to be perceptible by those with color vision deficiencies. Seaborn's `cubehelix` palette is a good choice, as it was designed specifically with color blindness in mind.

# %% [markdown]
# **Step 5:** Begin your research! Give yourself plenty of time to build your visualization or model. If you have any questions along the way, please email nsdc@nebigdatahub.org or write a message in the #[tdsp-community Slack Channel](https://join.slack.com/t/nsdcorps/shared_invite/zt-1h64t1e2p-La0AgU_HhymWUEGFQEcb3w).

# %% [markdown]
# **TO DO:** List the research question(s) you've chosen and why! Maybe you chose this question because it can help a community of interest or because it is similar to research you've completed in a class setting. Share your thoughts below.
#
# > * Are there specific zip codes in NYC that consistently experience high motor vehicle crashes over the past ten years? If so, are there any patterns or trends that emerge year after year? I chose this question because I think it's interesting that the majority of crashes are based in Brooklyn. I'm interested to dig deeper and see if the zip codes will reflect a yearly crash count that is high in certain areas of NYC and if there are any patterns.

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into your data and to support your research question.

# %% [markdown]
# Milestone #5 Question
#
# Are there specific zip codes in NYC that consistently experience high motor vehicle crashes over the past ten years? If so, are there any patterns or trends that emerge year after year?

# %% [markdown]
# # <font color='ORANGE'>**PART 1: PREPARE AND ASSESS THE DATASET**</font>

# %% [markdown]
# The data needed from the dataset is date, zip code, and crash count. Missing data will also be assessed.
#
# Following Milestone #1 steps, I will prepare the data first by setting up libraries and installing packages here.

# %% [markdown]
# Step 1: Import libraries with short names

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# Step 2: Access the data by mounting google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read the data using pandas read_csv function

# %%
# TODO: Read the data using pandas read_csv function
data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250106.csv")
# Out:
# <ipython-input-47-33082758963b>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Motor_Vehicle_Collisions_-_Crashes_20250106.csv")

# %% [markdown]
# Step 3: Check the dataset for missing values in the zip code and crash date. Also, count the number of values for collision_id to determine crash count

# %%
#Leverage the isnull() and sum() functions to find the number of missing values in the zip code and date column
zip_code_missing = data['ZIP CODE'].isnull().sum()
crash_date_missing = data['CRASH DATE'].isnull().sum()

#Turn the missing value counts into percentages
zip_code_missing_percentage = (zip_code_missing / len(data)) * 100
crash_date_missing_percentage = (crash_date_missing / len(data)) * 100

#count total number of collisions using unique identifier collisions_id
total_collisions = data['COLLISION_ID'].nunique()

#Return counts and percentages of missing values in the column
missing_data = pd.DataFrame({
    'Missing Value': [zip_code_missing, crash_date_missing],
    'Percentage (%)': [zip_code_missing_percentage, crash_date_missing_percentage]
    }, index =['ZIP CODE', 'CRASH DATE'])

missing_data.sort_values(by='Percentage (%)', ascending=False)

#display results
print(missing_data)
print(f'\nTotal number of collisions: {total_collisions}')
# Out:
#             Missing Value  Percentage (%)
# ZIP CODE           665926        31.01297
# CRASH DATE              0         0.00000
#
# Total number of collisions: 2147250

# %% [markdown]
# According to the results above, about 31% (665926) of the ZIP CODE column is missing from the dataset. As explained in Milestone #2 of TDSP, this could result from incomplete data entry or crashes happening in areas where zip code information isn't easily accessible. Since 31% is a substantial portion of the data, I will investigate whether the missing data is random and assess how it might affect the research.

# %% [markdown]
# To determine the significance of the missing data, I will first examine the locations of the missing zip codes. I will analyze the missing data in other location-related fields, such as "LOCATION", "LONGITUDE," "LATITUDE," "BOROUGH," and "ON STREET NAME." If the percentage of missing data in these fields is smaller, I will use them to identify the locations of the missing zip codes. Additionally, I will assess the percentage of missing data that is simultaneous in these fields and the zip codes themselves to further evaluate the extent of the missing data.

# %% [markdown]
# Step 4: Look at the percentage of missing data in other location-related fields: Borough, Latitude, Longitude, Location and On Street Name

# %%
#Leverage the isnull() and sum() functions to find the number of missing values in each column
zip_code_missing = data['ZIP CODE'].isnull().sum()
latitude_missing = data['LATITUDE'].isnull().sum()
longitude_missing = data['LONGITUDE'].isnull().sum()
borough_missing = data['BOROUGH'].isnull().sum()
on_street_name_missing = data['ON STREET NAME'].isnull().sum()
location_missing = data['LOCATION'].isnull().sum()

#Turn the missing value counts into percentages
zip_code_missing_percentage = (zip_code_missing / len(data)) * 100
latitude_missing_percentage = (latitude_missing / len(data)) * 100
longitude_missing_percentage = (longitude_missing / len(data)) * 100
borough_missing_percentage = (borough_missing / len(data)) * 100
on_street_name_missing_percentage = (on_street_name_missing / len(data)) * 100
location_missing_percentage = (location_missing / len(data)) * 100

#count total number of collisions using unique identifier collisions_id
total_collisions = data['COLLISION_ID'].nunique()

#Return counts and percentages of missing values in the column
missing_data = pd.DataFrame({
    'Missing Value': [zip_code_missing, location_missing, latitude_missing,
                      longitude_missing, borough_missing,on_street_name_missing],
    'Percentage (%)': [zip_code_missing_percentage, location_missing_percentage,
                       latitude_missing_percentage, longitude_missing_percentage,
                       borough_missing_percentage, on_street_name_missing_percentage]
    }, index =['ZIP CODE', 'LOCATION', 'LATITUDE', 'LONGITUDE', 'BOROUGH',
               'ON STREET NAME' ])

missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                 Missing Value  Percentage (%)
# ZIP CODE               665926       31.012970
# BOROUGH                665663       31.000722
# ON STREET NAME         461111       21.474491
# LOCATION               239548       11.156037
# LATITUDE               239548       11.156037
# LONGITUDE              239548       11.156037

# %% [markdown]
# Based on the results above, I will select location to compare the missing zip codes because it is the field with the least amount of missing data. Latitude and Longitude represent the same data so I will stick to Location alone. Before looking at the map, I want to look at if there is any data missing from both location and zip code.

# %%
# Calculate the number of rows where all three fields are missing
all_missing_count = data[['LATITUDE', 'LONGITUDE', 'ZIP CODE']].isnull().all(axis=1).sum()

# Calculate the total number of rows
total_rows = len(data)

# Calculate the percentage
all_missing_percentage = (all_missing_count / total_rows) * 100

# Display the percentage
print(f"Percentage of rows in all 3 fields missing: {all_missing_percentage:.2f}%")
# Out:
# Percentage of rows in all 3 fields missing: 9.41%

# %% [markdown]
# Since the percentage of missing data in all three fields and latitude and longitude is low, I will look at a map of the missing data from the Zip Code field based on these fields.
#
# ---

# %% [markdown]
# Step 5: Geospatial analysis of missing zip codes based on location field

# %%
import folium

# Filter for data with missing zip codes
missing_zip_data = data[data['ZIP CODE'].isnull()]

# random sample of 1000 rows
missing_zip_data = missing_zip_data.sample(n=1000, random_state=42)

# Create a folium map centered on NYC
missing_zip_map = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Iterate through data and add markers
for index, row in missing_zip_data.iterrows():
    if pd.notna(row['LATITUDE']) and pd.notna(row['LONGITUDE']):
        folium.CircleMarker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            radius=5,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.6
        ).add_to(missing_zip_map)

#display map
display(missing_zip_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_738d1a46878001764d53b6b1c90f80dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_738d1a46878001764d53b6b1c90f80dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_738d1a46878001764d53b6b1c90f80dd = L.map(
#                 &quot;map_738d1a46878001764d53b6b1c90f80dd&quot;,
#                 {
#                     center: [40.73061, -73.935242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_760930e8ef4797ae3b4d3666764f4e88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_760930e8ef4797ae3b4d3666764f4e88.addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_f215bf97832c0b2dba781112ede6ddd4 = L.circleMarker(
#                 [40.786083, -73.796455],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_09095123ae26acf7e9b019dcf50df13f = L.circleMarker(
#                 [40.66434, -73.93155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_2e6bca5862dc86f65476a81b7d5fb613 = L.circleMarker(
#                 [40.815544, -73.956924],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_ac75f554727e98ddcfe1c6695bd58257 = L.circleMarker(
#                 [40.674, -73.8721],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_c0d8ffa81dfbebcb5017ade73dcdbe98 = L.circleMarker(
#                 [40.644142, -73.957924],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_01b3a57ef66a6804fada9ad39101b3b1 = L.circleMarker(
#                 [40.676872, -73.94985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_738d1a46878001764d53b6b1c90f80dd);
#
#
#             var circle_marker_2f7b3e743eec897db1975532eb466857 = L.circleMarker(
#                 [40.845226, -73.91309],
#                 {&quot;bubbl

# %% [markdown]
# The geospatial analysis reveals a somewhat random distribution of missing zip code data across the region. While there's a slight concentration along highways, this pattern seems consistent across all boroughs. To streamline the analysis and minimize potential complications, the dataset will be used with the missing zip code data excluded. A note outlining the limitations of the data will be included.
#
# Note: It's important to acknowledge that approximately 31% of the dataset's zip code information is missing. While a geospatial analysis suggests a relatively random distribution of these missing values, it's possible that this exclusion could introduce a bias into the analysis. Additionally, there are instances where latitude, longitude, and zip code information are simultaneously missing, affecting 9% of the map data. These findings and conclusions presented should be interpreted with this limitation in mind.

# %% [markdown]
# Step 6: Data cleaning: remove the rows that are missing zip code data

# %%
data_cleaned = data.dropna(subset=['ZIP CODE'])

missing_count = data_cleaned[['ZIP CODE']].isnull().all(axis=1).sum()

# Calculate the total number of rows
total_rows = len(data_cleaned)

# Calculate the percentage
missing_percentage = (missing_count / total_rows) * 100

# Display the percentage
print(f"Percentage of zip code data missing: {missing_percentage:.2f}%")
# Out:
# Percentage of zip code data missing: 0.00%

# %% [markdown]
# I included code to show that the new data frame data_cleaned has no missing zip code data.

# %% [markdown]
# # <font color = "orange">**PART 2: IDENTIFY TOP 10 ZIP CODES BY CRASH FREQUENCY**</font>

# %% [markdown]
# Step 1: Group and aggregate data_cleaned by zip code and year, and calculate the total crashes for each zip code across ten years, 2014-2024 and select top ten zip codes

# %%
# Calculate total crashes for each zip code across all years
# Create the zip_code_crash_counts DataFrame first
zip_code_crash_counts = data_cleaned.groupby('ZIP CODE')['COLLISION_ID'].count().reset_index()
zip_code_crash_counts.rename(columns={'COLLISION_ID': 'Crash Count'}, inplace=True)  # Rename the column for clarity


# Calculate total crashes for each zip code across all years
zip_code_total_crashes = zip_code_crash_counts.groupby('ZIP CODE')['Crash Count'].sum().reset_index()

# Sort by total crash counts in descending order and select top 10
top_10_zip_codes = zip_code_total_crashes.sort_values(by=['Crash Count'], ascending=False).head(10).reset_index(drop=True)
top_10_zip_codes.index = top_10_zip_codes.index + 1
# Get the list of top 10 zip codes
top_10_zip_codes_list = top_10_zip_codes['ZIP CODE'].tolist()
#display toptt ten zip codes based on crash count
display(top_10_zip_codes)
# Out:
#    ZIP CODE  Crash Count
# 1   11207.0        22009
# 2   11236.0        15725
# 3   11234.0        14272
# 4   11203.0        14269
# 5   11212.0        14230
# 6   11208.0        14195
# 7   11385.0        14165
# 8   11101.0        13958
# 9   11226.0        13485
# 10  11434.0        12906

# %% [markdown]
# Step 2: Plot a graph depicting the top 10 zip codes based on year and crash count

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert 'CRASH DATE' to datetime
data_cleaned['CRASH DATE'] = pd.to_datetime(data_cleaned['CRASH DATE'])

# Filter data for top 10 zip codes 2015-2024
top_10_zip_codes_list = top_10_zip_codes['ZIP CODE'].tolist()  # Get the list of top 10 zip codes
filtered_data = data_cleaned[
    (data_cleaned['ZIP CODE'].isin(top_10_zip_codes_list)) &
    (data_cleaned['CRASH DATE'].dt.year >= 2015) &
    (data_cleaned['CRASH DATE'].dt.year <= 2024)
]

# Group by zip code and year, and calculate total crashes
zip_code_year_counts = filtered_data.groupby(['ZIP CODE', filtered_data['CRASH DATE'].dt.year])['COLLISION_ID'].count().reset_index()
zip_code_year_counts.rename(columns={'COLLISION_ID': 'Crash Count', 'CRASH DATE': 'Crash Year'}, inplace=True) # Renamed CRASH DATE to Crash Year

# Create the line graph
plt.figure(figsize=(12, 6))

for zip_code in top_10_zip_codes_list:
    zip_code_data = zip_code_year_counts[zip_code_year_counts['ZIP CODE'] == zip_code]
    plt.plot(zip_code_data['Crash Year'], zip_code_data['Crash Count'], label=zip_code)

plt.xlabel('Year')
plt.ylabel('Crash Count')
plt.title('Crash Counts for Top 10 Zip Codes (2015-2024)')
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1))  # Adjust legend location as needed
plt.grid(True)
plt.show()
# Out:
# <ipython-input-54-495878702fd5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['CRASH DATE'] = pd.to_datetime(data_cleaned['CRASH DATE'])

# %% [markdown]
# The graph above reveals that zip code 11207 consistently exhibits high crash counts relative to other zip codes, suggesting that specific local factors contribute to crashes in this area. There is a widespread dip in crash counts around 2020, likely attributable to the COVID-19 pandemic and its impact on traffic volume. Prior to the pandemic, there appears to be a slight upward trend in crash counts. Following the 2020 dip, crash counts generally decrease, although with some fluctuations. Since 2022, there has been a relative plateau with a slight upward trend, indicating a potential return to pre-pandemic levels.

# %% [markdown]
# # <font color= "orange"> PART 3: FURTHER ANALYSIS

# %% [markdown]
# For this part of the project, I will carry out further analysis to extract more information about the results.

# %% [markdown]
# Step 1: **Seasonal Trends** - The previous line graph shows us the yearly trends of the top ten zip codes, but crashes might also have seasonal patterns (e.g. there could be more crashes in the winter due to icy roads). In this next part, I want to see if there are any patterns that can provide deeper insights.

# %%
# Group by zip code and month, and calculate total crashes
zip_code_month_counts = filtered_data.groupby(['ZIP CODE', filtered_data['CRASH DATE'].dt.month])['COLLISION_ID'].count().reset_index()
zip_code_month_counts.rename(columns={'COLLISION_ID': 'Crash Count', 'CRASH DATE': 'Crash Month'}, inplace=True)

#Create the line graph
plt.figure(figsize=(12, 6))

for zip_code in top_10_zip_codes_list:
    zip_code_data = zip_code_month_counts[zip_code_month_counts['ZIP CODE'] == zip_code]
    plt.plot(zip_code_data['Crash Month'], zip_code_data['Crash Count'], label=zip_code)

plt.xlabel('Month')
plt.ylabel('Crash Count')
plt.title('Crash Counts for Top 10 Zip Codes by Month')
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# The graph above reveals a fluctuating trend in crash counts throughout the year. Between January and May, there is a noticeable up-and-down pattern, with crash counts generally increasing towards summer. A peak in crash counts typically occurs between October and December, followed by a gradual decrease into the new year. Despite this overall trend, fluctuations persist throughout the year. While January, March, and May tend to experience higher crash counts for all zip codes initially, the patterns vary across different zip codes after May. Some zip codes continue to exhibit alternating periods of higher and lower crash counts in the same manner (i.e. July, August, etc.) while others show a reversal of this pattern (highs are June, September, etc.).
#
# Summer likely sees a rise in crashes due to increased traffic volume, as travel and tourism tend to increase during this time. With schools out for the summer, there's a greater likelihood of students and newer drivers being on the road. Pleasant summer weather also encourages more people to enjoy outdoor activities, leading to increased pedestrian and cyclist traffic. This trend continues into the fall and winter holiday season, with increased travel and visitors, contributing to higher crash counts. Many people are also out and about for shopping and social gatherings during these months, further increasing the risk of accidents.

# %% [markdown]
# Step 2: **Location of Zip Codes** For this part of the analysis, I want to look at where the top ten zip codes are located to assess if there could be a geographical factor

# %%
# !pip install folium
import folium
import pandas as pd

# Define a function to get latitude and longitude for a zip code
def get_zip_code_coordinates(zip_code):

    # Returns approximate coordinates for the top 10 zip codes
    #Coordinates selected by random within each zip code using google maps
    coordinates = {
        11207: (40.672053, -73.893470),
        11236: (40.643674, -73.902181),
        11234: (40.622006, -73.922800),
        11212: (40.660986, -73.909831),
        11203: (40.651309, -73.934815),
        11208: (40.673958, -73.870582),
        11385: (40.703603, -73.892631),
        11101: (40.743899, -73.935890),
        11226: (40.645366, -73.957548),
        11434: (40.675627, -73.779128),
    }
    return coordinates.get(zip_code)

# Create a Folium map centered on NYC, using a different name: top_zip_codes_map
top_zip_codes_map = folium.Map(location=[40.7128, -74.0060], zoom_start=11)

# Add markers for each zip code
for index, row in top_10_zip_codes.iterrows():
    zip_code = row['ZIP CODE']
    latitude, longitude = get_zip_code_coordinates(zip_code)
    if latitude and longitude:
        folium.Marker(
            location=[latitude, longitude],
            popup=f"Zip Code: {zip_code}",
            icon=folium.Icon(color="red", icon="info-sign"),
        ).add_to(top_zip_codes_map)

# Display the map
top_zip_codes_map
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.4)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2024.12.14)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f167abf00c5da2ea03aa89812a0dc0c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f167abf00c5da2ea03aa89812a0dc0c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f167abf00c5da2ea03aa89812a0dc0c1 = L.map(
#                 &quot;map_f167abf00c5da2ea03aa89812a0dc0c1&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05afaff59327a9d360661d0a0d27aa27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05afaff59327a9d360661d0a0d27aa27.addTo(map_f167abf00c5da2ea03aa89812a0dc0c1);
#
#
#             var marker_d8e1982d7ea1b036ef9a0fb4ca05c628 = L.marker(
#                 [40.672053, -73.89347],
#                 {
# }
#             ).addTo(map_f167abf00c5da2ea03aa89812a0dc0c1);
#
#
#             var icon_a2f6909e70459b80efb8b47a28c15519 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d8e1982d7ea1b036ef9a0fb4ca05c628.setIcon(icon_a2f6909e70459b80efb8b47a28c15519);
#
#
#         var popup_329c2f011354d7e1a82fbee0810623a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f177b44f5db22883d5000e8c8b65671 = $(`&lt;div id=&quot;html_9f177b44f5db22883d5000e8c8b65671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zip Code: 11207.0&lt;/div&gt;`)[0];
#                 popup_329c2f011354d7e1a82fbee0810623a0.setContent(html_9f177b44f5db22883d5000e8c8b65671);
#
#
#
#         marker_d8e1982d7ea1b036ef9a0fb4ca05c628.bindPopup(popup_329c2f011354d7e1a82fbee0810623a0)
#         ;
#
#
#
#
#             var marker_838541f5604b74fe4217670173d6ee59 = L.marker(
#                 [40.643674, -73.902181],
#                 {
# }
#             ).addTo(map_f167abf00c5da2ea03aa89812a0dc0c1);
#
#
#             var icon_c7dec953b5e7925c9de5a7af9e62cb2a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_838541f5604b74fe4217670173d6ee59.setIcon(icon_c7dec953b5e7925c9de5a7af9e62cb2a);
#
#
#         var popup_c39050803d0a0706ae08b6b7eca164b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dc3f268b32136abcbaab797e5c6055d = $(`&lt;div id=&quot;html_7dc3f268b32136abcbaab797e5c6055d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zip Code: 11236.0&lt;/div&gt;`)[0];
#                 popup_c39050803d0a0706ae08b6b7eca164b4.setContent(html_7dc3f268b32136abcbaab797e5c6055d);
#
#
#
#         marker_838541f5604b74fe4217670173d6ee59.bindPopup(popup_c39050803d0a0706ae08b6b7eca164b4)
#         ;
#
#
#
#
#             var marker_042be1f113b4b2761aa877309685bce8 = L.marker(
#                 [40.622006, -73.9228],
#                 {
# }
#             ).addTo(map_f167abf00c5da2ea03aa89812a0dc0c1);
#
#
#             var icon_c943ececbb22da1dabbb33a1c0fe4a59 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_042be1f113b4b2761aa877309685bce8.setIcon(icon_c943ececbb22da1dabbb33a1c0fe4a59);
#
#
#         var popup_c53f0ddae8eb26a4dc031aee47bbc5dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b68ff50854c9ab4b71a8d30bc5d2506a = $(`&lt;div id=&quot;html_b68ff50854c9ab4b71a8d30bc5d2506a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zip Code: 11234.0&lt;/div&gt;`)[0];
#                 popup_c53f0ddae8eb26a4dc031aee47bbc5dd.setContent(html_b68ff50854c9ab4b71a8d30bc5d2506a);
#
#
#
#         marker_042be1f113b4b2761aa877309685bce8.bindPopup(popup_c53f0ddae8eb26a4dc031aee47bbc5dd)
#         ;
#
#
#
#
#             var marker_00c95d18ec052f87777fa8d882dd4a80 = L.marker(
#                 [40.651309, -73.934815],
#                 {
# }
#             ).addTo(map_f167abf00c5da2ea03aa89812a0dc0c1);
#
#
#             var icon_5799f39f2ea60a6f4674bb79a3cd8b37 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot

# %% [markdown]
# The map above reveals that the majority of the top ten zip codes are close to each other. Zip codes 11208, 11207, 11236, 11212, 11203, 11226 are approximately within a 5 mile radius. 8/10 top ten zip codes are within Brooklyn. Their closeness to each other and presence in Brooklyn, might indicate that there might be certain local infrastructure in this area that might increase the crash count. Brooklyn is the most populated borough in New York, so it could also be due to traffic volume.

# %% [markdown]
# # <font color = "orange">PART 4: CONCLUSION </font>

# %% [markdown]
# The analysis aimed to identify and understand trends in motor vehicle crashes in NYC specifically focusing on zip codes with consistently high crash frequencies over the past ten years. The findings reveal important insights into geographical, temporal, and potentially demographic factors contributing to these crashes.
#
# Key findings:
# - Geographic Clusters: a significant portion of the top 10 zip codes with high crash frequencies are geographically clustered within Brooklyn and in close proximity to each other. The clustering suggests potential contributing factors specific to these areas.
#
# - Seasonal Trends: crash counts exhibit fluctations throughout the year, with peaks typically observed during summer months and the fall/winter holiday season. These patterns likely reflecty increased traffic volume, as well as potentially hazardous weather conditions during winter.
#
# - Zip Code 11207: this zip code consistently exhibited the highest crash counts compared to the other 10 zip codes, indicating the presence of local factors contributing to increased crash occurences in this area. Further investigation focusing on this specific location is recommended based on these findings, as well as the surrounding zip codes.
#
# - Demographic factors: while not explored in this analysis, demographic factors could play a role in the observed trends due to geographic clustering. Further analysis should incorporate demographic data such as population density, age, and socioeconomic factors on crash occurrences in specific areas.

# %% [markdown]
# Recommendation: The geographic clustering in Brooklyn should be considered for further investigation, potentially exploring infrastructure or other local factors, with targeted safety measures during peak seasonal periods.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #6 - Virtual Poster Board Creation: Data Storytelling**</font>
#
# GOAL: The main goal of this milestone is to create a one page, virtual poster board to portray your research findings and recommendations! Your poster may be shared with the Department of Transportation and Federal Highway Authority.

# %% [markdown]
# Within your poster, summarize your research question, your reasoning for selecting your data visualization or model choices, and key insights from your data analysis. You may also wish to include your outstanding research questions that could not be answered by the dataset and why.
#
# **Be sure to answer the following on your virtual poster board:** Based on your research insights, what recommendations would you share with the Department of Transportation and Federal Highway Authority to make roads safer for vulnerable road users? Why?
#
# **Additionally, be sure to cite all relevant sources that you referred to throughout this project on your poster board (MLA or APA citation preferred). List acknowlegdments if you received any support from mentors, professors, professionals, etc. throughout your journey.**

# %% [markdown]
#  Please use the following resources to get started!
#
#
# *   [Virtual Poster Board Template](https://nebigdatahub.org/wp-content/uploads/2024/01/Copy-of-dsi-poster.ppt-48-×-36-in.pdf) - Your one-page, virtual poster may be created in PowerPoint, Google Slides, Canva, etc. Choose what you are most comfortable with!
# * [ Data Storytelling: How to Effectively Tell a Story with Data](https://online.hbs.edu/blog/post/data-storytelling)
#
# * [  Consider how your visualization(s) might appear to people with varying abilities ](https://chartability.fizz.studio/)
# *  [Understand your audience for an optimal presentation](https://hbr.org/2013/04/how-to-tell-a-story-with-data)
#
#
# Once completed, please use the [following TDSP Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) to share your Google Colab Notebook and your one-page, virtual project poster with the NSDC HQ Team.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🚗<font color='crimson'> **Thank you for completing the project!**</font> 🚗
#
# We are one step closer to making roads safer for all. [Please submit all materials to the NSDC HQ team](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) in order to receive a certificate of completion. Do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
